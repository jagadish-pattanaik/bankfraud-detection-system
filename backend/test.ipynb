# %%
import pandas as pd

# Load the dataset used for training
df = pd.read_csv("data/Banking_Cleaned.csv")

# Remove the target column if present
if "F3924" in df.columns:
    df = df.drop(columns=["F3924"])

# Save the first 10 rows
df.head(10).to_csv("test_upload.csv", index=False)

print("Created test_upload.csv")
# Out:
# Created test_upload.csv
